# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_csv('data1.csv')

# %% [markdown]
# Menampilkan nama kolom dan tipe datanya

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3327 entries, 0 to 3326
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Timestamp          3322 non-null   object
#  1   Email Address      3323 non-null   object
#  2   Nama Peminjam      3323 non-null   object
#  3   Jurusan / Prodi    3327 non-null   object
#  4   Kelas              3323 non-null   object
#  5   Nama Laboratorium  3322 non-null   object
#  6   Keperluan          3322 non-null   object
#  7   Tanggal            3322 non-null   object
#  8   waktu              3322 non-null   object
#  9   No HP WA           3322 non-null   object
#  10  KPM / KTP / SIM    3322 non-null   object
#  11  Unnamed: 11        2 non-null      object
# dtypes: object(12)
# memory usage: 312.0+ KB

# %% [markdown]
# Menampilkan data pada data frame

# %%
df
# Out:
#              Timestamp                    Email Address  \
# 0     2/1/2024 8:04:38          kurniawanm061@gmail.com
# 1     2/1/2024 8:31:13  fernandico.geovardo01@gmail.com
# 2     2/1/2024 9:00:05                 zxxfrn@gmail.com
# 3     2/1/2024 9:39:51         zakiramadan019@gmail.com
# 4     2/1/2024 9:54:15          rakhelguntur0@gmail.com
# ...                ...                              ...
# 3322               NaN                              NaN
# 3323               NaN                              NaN
# 3324               NaN                              NaN
# 3325               NaN                              NaN
# 3326               NaN
#
#                Nama Peminjam               Jurusan / Prodi    Kelas  \
# 0                m.kurniawan         Manajemen Informatika      MI4
# 1                 Fernandico  Teknik Informatika Bilingual        A
# 2           Muhammad Zhafran  Teknik Informatika Bilingual       p2
# 3         Zaki Tirta Ramadan               Teknik Komputer     TK4B
# 4     Rakhel Guntur Fahreza        Komputerisasi Akuntansi      Ka4
# ...                      ...                           ...      ...
# 3322                     NaN                                    NaN
# 3323                     NaN                                    NaN
# 3324                     NaN                                    NaN
# 3325                     NaN
# 3326                                                            NaN
#
#                                       Nama Laboratorium         Keperluan  \
# 0                                      RUANG COMLAB 1.1            kuliah
# 1             Lab. RPL & Sistem Informasi (Comlab Lt.3)             aslab
# 2     Lab. Kecerdasan Buatan & Grafika Komp (Comlab ...            projek
# 3         Lab. Jaringan Komputer & Komdat (Comlab Lt.2)    Peminjam Kunci
# 4       Lab. Struktur Data & SI Akuntansi (Comlab Lt.3)  Praktikum zahir
# ...                                                 ...               ...
# 3322                                                NaN               NaN
# 3323                                                NaN               NaN
# 3324                                                NaN               NaN
# 3325                                                NaN               NaN
# 3326                                                NaN               NaN
#
#        Tanggal       waktu      No HP WA  \
# 0     2/1/2024  8:04:00 AM  082179439575
# 1     2/1/2024  8:30:00 AM  089626033557
# 2     2/1/2024  8:59:00 AM  089530694913
# 3     2/1/2024  9:38:00 AM  083803960442
# 4     2/1/2024  9:53:00 AM  085267061621
# ...        ...         ...           ...
# 3322       NaN         NaN           NaN
# 3323       NaN         NaN           NaN
# 3324       NaN         NaN           NaN
# 3325       NaN         NaN           NaN
# 3326       NaN         NaN           NaN
#
#                                         KPM / KTP / SIM Unnamed: 11
# 0     https://drive.google.com/open?id=1mt7HtvvXwr90...         NaN
# 1     https://drive.google.com/open?id=1SQiIZBXVE-q2...         NaN
# 2     https://drive.google.com/open?id=1TyjfYbBBrSky...         NaN
# 3     https://drive.google.com/open?id=1hnejGhgCT3F9...         NaN
# 4     https://drive.google.com/open?id=1EJrIrs7GC-Ng...         NaN
# ...                                                 ...         ...
# 3322                                                NaN         NaN
# 3323                                                NaN         NaN
# 3324                                                NaN         NaN
# 3325                                                NaN         NaN
# 3326                                                NaN         NaN
#
# [3327 rows x 12 columns]

# %% [markdown]
# Menampilkan jumlah data kosong pada kolom dan persentasenya

# %%
missing_data = df.isnull().sum()
missing_data
missing_data = missing_data[missing_data > 0].sort_values(ascending=False)
missing_percentage = (missing_data / len(df)) * 100
missing_summary = pd.DataFrame({'Missing Values': missing_data, 'Percentage': missing_percentage})
missing_summary
# Out:
#                    Missing Values  Percentage
# Unnamed: 11                  3325   99.939886
# Nama Laboratorium               5    0.150286
# Timestamp                       5    0.150286
# No HP WA                        5    0.150286
# waktu                           5    0.150286
# Tanggal                         5    0.150286
# Keperluan                       5    0.150286
# KPM / KTP / SIM                 5    0.150286
# Email Address                   4    0.120228
# Nama Peminjam                   4    0.120228
# Kelas                           4    0.120228

# %% [markdown]
# Menghapus kolom yang memiliki jumlah data kosong lebih dari 50%

# %%
columns_to_drop = missing_percentage[missing_percentage >= 50].index
df_cleaned = df.drop(columns=columns_to_drop)

# %% [markdown]
# Menampilkan kembali jumlah data kosong

# %%
missing_data = df_cleaned.isnull().sum()
missing_data
missing_data = missing_data[missing_data > 0].sort_values(ascending=False)
missing_percentage = (missing_data / len(df_cleaned)) * 100
missing_summary = pd.DataFrame({'Missing Values': missing_data, 'Percentage': missing_percentage})
missing_summary
# Out:
#                    Missing Values  Percentage
# Timestamp                       5    0.150286
# Keperluan                       5    0.150286
# No HP WA                        5    0.150286
# Nama Laboratorium               5    0.150286
# waktu                           5    0.150286
# Tanggal                         5    0.150286
# KPM / KTP / SIM                 5    0.150286
# Email Address                   4    0.120228
# Nama Peminjam                   4    0.120228
# Kelas                           4    0.120228

# %%
df_cleaned.tail()
# Out:
#      Timestamp Email Address Nama Peminjam Jurusan / Prodi    Kelas  \
# 3322       NaN           NaN           NaN                      NaN
# 3323       NaN           NaN           NaN                      NaN
# 3324       NaN           NaN           NaN                      NaN
# 3325       NaN           NaN           NaN
# 3326       NaN                                                  NaN
#
#      Nama Laboratorium Keperluan Tanggal waktu No HP WA KPM / KTP / SIM
# 3322               NaN       NaN     NaN   NaN      NaN             NaN
# 3323               NaN       NaN     NaN   NaN      NaN             NaN
# 3324               NaN       NaN     NaN   NaN      NaN             NaN
# 3325               NaN       NaN     NaN   NaN      NaN             NaN
# 3326               NaN       NaN     NaN   NaN      NaN             NaN

# %% [markdown]
# Menghapus baris yang memiliki data kosong lebih dari 50%

# %%
threshold = len(df_cleaned.columns) / 2
df_cleaned = df_cleaned.dropna(thresh=threshold)
df_cleaned
# Out:
#                Timestamp                       Email Address  \
# 0       2/1/2024 8:04:38             kurniawanm061@gmail.com
# 1       2/1/2024 8:31:13     fernandico.geovardo01@gmail.com
# 2       2/1/2024 9:00:05                    zxxfrn@gmail.com
# 3       2/1/2024 9:39:51            zakiramadan019@gmail.com
# 4       2/1/2024 9:54:15             rakhelguntur0@gmail.com
# ...                  ...                                 ...
# 3317   4/24/2025 9:27:12  09011282126080@student.unsri.ac.id
# 3318  4/24/2025 10:40:30              putrifazza88@gmail.com
# 3319  4/24/2025 10:49:27             destaanggrizy@gmail.com
# 3320  4/24/2025 11:39:51               mhdakbartgm@gmail.com
# 3321  4/24/2025 11:56:27              ruqi.mqadar2@gmail.com
#
#                Nama Peminjam               Jurusan / Prodi          Kelas  \
# 0                m.kurniawan         Manajemen Informatika            MI4
# 1                 Fernandico  Teknik Informatika Bilingual              A
# 2           Muhammad Zhafran  Teknik Informatika Bilingual             p2
# 3         Zaki Tirta Ramadan               Teknik Komputer           TK4B
# 4     Rakhel Guntur Fahreza        Komputerisasi Akuntansi            Ka4
# ...                      ...                           ...            ...
# 3317      Ebenezer Hutahaean               Sistem Komputer  SK 8B REGULER
# 3318                   Fazza               Sistem Komputer           Sku8
# 3319         Desta Anggrizy                Teknik Komputer              -
# 3320          Muhammad Akbar         Manajemen Informatika          MI 4B
# 3321     Ruqi Muqa Ramadhan                Teknik Komputer           TK2B
#
#                                       Nama Laboratorium  \
# 0                                      RUANG COMLAB 1.1
# 1             Lab. RPL & Sistem Informasi (Comlab Lt.3)
# 2     Lab. Kecerdasan Buatan & Grafika Komp (Comlab ...
# 3         Lab. Jaringan Komputer & Komdat (Comlab Lt.2)
# 4       Lab. Struktur Data & SI Akuntansi (Comlab Lt.3)
# ...                                                 ...
# 3317  Lab. Perangkat keras & Teknologi Komponen (Com...
# 3318    Lab. Elektronika & Sistem Digital (Comlab Lt.2)
# 3319      Lab. Jaringan Komputer & Komdat (Comlab Lt.2)
# 3320           Lab. Basis Data & Big Data (Comlab Lt.4)
# 3321                         RUANG Studio (Comlab Lt.4)
#
#                           Keperluan    Tanggal        waktu      No HP WA  \
# 0                            kuliah   2/1/2024   8:04:00 AM  082179439575
# 1                             aslab   2/1/2024   8:30:00 AM  089626033557
# 2                            projek   2/1/2024   8:59:00 AM  089530694913
# 3                    Peminjam Kunci   2/1/2024   9:38:00 AM  083803960442
# 4                  Praktikum zahir    2/1/2024   9:53:00 AM  085267061621
# ...                             ...        ...          ...           ...
# 3317                             TA  4/24/2025   9:26:00 AM  082269113481
# 3318                    Tugas akhir  4/24/2025  10:40:00 AM  081324784254
# 3319                    TUGAS AKHIR  4/24/2025  10:48:00 AM  082175205059
# 3320  Praktikum Pemrograman Visual   4/24/2025  11:40:00 AM  081278948316
# 3321    Interaksi manusia komputer   4/24/2025  11:55:00 AM  088287200638
#
#                                         KPM / KTP / SIM
# 0     https://drive.google.com/open?id=1mt7HtvvXwr90...
# 1     https://drive.google.com/open?id=1SQiIZBXVE-q2...
# 2     https://drive.google.com/open?id=1TyjfYbBBrSky...
# 3     https://drive.google.com/open?id=1hnejGhgCT3F9...
# 4     https://drive.google.com/open?id=1EJrIrs7GC-Ng...
# ...                                                 ...
# 3317  https://drive.google.com/open?id=1ezZfulXWQZ0U...
# 3318  https://drive.google.com/open?id=15qkHvTR3bOiA...
# 3319  https://drive.google.com/open?id=13g7CC-zDrIGb...
# 3320  https://drive.google.com/open?id=1DkGalPB80e8o...
# 3321  https://drive.google.com/open?id=1mzRH5BVSxxNm...
#
# [3322 rows x 11 columns]

# %% [markdown]
# Menampilkan kembali jumlah data kosong

# %%
df_cleaned.isnull().sum()
# Out:
# Timestamp            0
# Email Address        0
# Nama Peminjam        0
# Jurusan / Prodi      0
# Kelas                0
# Nama Laboratorium    0
# Keperluan            0
# Tanggal              0
# waktu                0
# No HP WA             0
# KPM / KTP / SIM      0
# dtype: int64

# %% [markdown]
# Menghapus kolom yang tidak diperlukan

# %%
df_cleaned = df_cleaned.drop(columns=['Email Address', 'Kelas', 'Nama Peminjam', 'Tanggal', 'waktu', 'No HP WA', 'KPM / KTP / SIM'])
df_cleaned.head()
# Out:
#           Timestamp               Jurusan / Prodi  \
# 0  2/1/2024 8:04:38         Manajemen Informatika
# 1  2/1/2024 8:31:13  Teknik Informatika Bilingual
# 2  2/1/2024 9:00:05  Teknik Informatika Bilingual
# 3  2/1/2024 9:39:51               Teknik Komputer
# 4  2/1/2024 9:54:15       Komputerisasi Akuntansi
#
#                                    Nama Laboratorium         Keperluan
# 0                                   RUANG COMLAB 1.1            kuliah
# 1          Lab. RPL & Sistem Informasi (Comlab Lt.3)             aslab
# 2  Lab. Kecerdasan Buatan & Grafika Komp (Comlab ...            projek
# 3      Lab. Jaringan Komputer & Komdat (Comlab Lt.2)    Peminjam Kunci
# 4    Lab. Struktur Data & SI Akuntansi (Comlab Lt.3)  Praktikum zahir

# %%
jurusan_counts = df_cleaned['Jurusan / Prodi'].value_counts()

# Membuat visualisasi
plt.figure(figsize=(12, 8))
sns.barplot(x=jurusan_counts.values, y=jurusan_counts.index, palette='viridis')
plt.title('Distribusi Jurusan / Prodi', fontsize=16)
plt.xlabel('Jumlah', fontsize=12)
plt.ylabel('Jurusan / Prodi', fontsize=12)
plt.show()
# Out:
# C:\Users\asus_utomo\AppData\Local\Temp\ipykernel_18124\2481991448.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=jurusan_counts.values, y=jurusan_counts.index, palette='viridis')

# %%
jurusan_counts = df_cleaned['Jurusan / Prodi'].value_counts()
print(jurusan_counts)
# Out:
# Jurusan / Prodi
# Sistem Komputer                 748
# Manajemen Informatika           686
# Teknik Komputer                 568
# Sistem Informasi Bilingual      563
# Teknik Informatika Bilingual    457
# Komputerisasi Akuntansi         299
# Magister Ilmu Komputer            1
# Name: count, dtype: int64

# %%
lab_counts = df_cleaned['Nama Laboratorium'].value_counts()

# Membuat visualisasi
plt.figure(figsize=(12, 8))
sns.barplot(x=lab_counts.values, y=lab_counts.index, palette='viridis')
plt.title('Distribusi Nama Laboratorium', fontsize=16)
plt.xlabel('Jumlah', fontsize=12)
plt.ylabel('Nama Laboratorium', fontsize=12)
plt.show()
# Out:
# C:\Users\asus_utomo\AppData\Local\Temp\ipykernel_18124\2494425843.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=lab_counts.values, y=lab_counts.index, palette='viridis')

# %%
lab_counts = df_cleaned['Nama Laboratorium'].value_counts()
print(lab_counts)
# Out:
# Nama Laboratorium
# Lab. Jaringan Komputer & Komdat (Comlab Lt.2)                    306
# Lab. Elektronika & Sistem Digital (Comlab Lt.2)                  285
# Lab. Pemrograman Lanjut (Diklat Lt.4)                            279
# Lab. Struktur Data & SI Akuntansi (Comlab Lt.3)                  276
# Lab. RPL & Sistem Informasi (Comlab Lt.3)                        249
# Lab. Pemrograman Dasar (Diklat Lt.3)                             230
# Lab. Pemrograman Internet (Diklat Lt.5)                          230
# Lab. Perangkat keras & Teknologi Komponen (Comlab Lt.3)          201
# Lab. Pengolahan Citra & Pengenalan Pola (Comlab Lt.3)            188
# Lab. Basis Data & Big Data (Comlab Lt.4)                         176
# Lab. Multimedia & Pemrograman Game (Comlab Lt.4)                 175
# Lab. Robotika, Sistem Kendali & Sistem Tertanam (Comlab Lt.2)    167
# RUANG COMLAB 1.1                                                 161
# RUANG 3 A                                                        149
# Lab. Studio (Comlab Lt.4)                                        109
# RUANG Studio (Comlab Lt.4)                                       101
# Lab. Kecerdasan Buatan & Grafika Komp (Comlab Lt.2)               33
# RUANG COMLAB 1.2                                                   5
# Lab. Pemograman Internet (Diklat Lt.5)                             1
#                                                                    1
# Name: count, dtype: int64

# %% [markdown]
# Mengubah tipe data kolom Timestamp dari object menjadi datetimes

# %%
df_cleaned['Timestamp'] = pd.to_datetime(df_cleaned['Timestamp'])

# %%
df_cleaned.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3322 entries, 0 to 3321
# Data columns (total 4 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Timestamp          3322 non-null   datetime64[ns]
#  1   Jurusan / Prodi    3322 non-null   object
#  2   Nama Laboratorium  3322 non-null   object
#  3   Keperluan          3322 non-null   object
# dtypes: datetime64[ns](1), object(3)
# memory usage: 129.8+ KB

# %% [markdown]
# Membuat kolom baru yaitu Hari berdasarkan nilai Timestamp

# %%
df_cleaned['Hari'] = df_cleaned['Timestamp'].dt.day_name()

# %%
df_cleaned['Hari'] = df_cleaned['Hari'].map({'Sunday': 'Minggu', 'Monday': 'Senin', 'Tuesday': 'Selasa', 'Wednesday': 'Rabu', 'Thursday': 'Kamis', 'Friday': 'Jumat', 'Saturday': 'Sabtu'})
df_cleaned.tail()
# Out:
#                Timestamp        Jurusan / Prodi  \
# 3317 2025-04-24 09:27:12        Sistem Komputer
# 3318 2025-04-24 10:40:30        Sistem Komputer
# 3319 2025-04-24 10:49:27        Teknik Komputer
# 3320 2025-04-24 11:39:51  Manajemen Informatika
# 3321 2025-04-24 11:56:27        Teknik Komputer
#
#                                       Nama Laboratorium  \
# 3317  Lab. Perangkat keras & Teknologi Komponen (Com...
# 3318    Lab. Elektronika & Sistem Digital (Comlab Lt.2)
# 3319      Lab. Jaringan Komputer & Komdat (Comlab Lt.2)
# 3320           Lab. Basis Data & Big Data (Comlab Lt.4)
# 3321                         RUANG Studio (Comlab Lt.4)
#
#                           Keperluan   Hari
# 3317                             TA  Kamis
# 3318                    Tugas akhir  Kamis
# 3319                    TUGAS AKHIR  Kamis
# 3320  Praktikum Pemrograman Visual   Kamis
# 3321    Interaksi manusia komputer   Kamis

# %%
hari_counts = df_cleaned['Hari'].value_counts()

# Membuat visualisasi
plt.figure(figsize=(10, 6))
sns.barplot(x=hari_counts.index, y=hari_counts.values, palette='viridis')
plt.title('Distribusi Data Hari', fontsize=16)
plt.xlabel('Hari', fontsize=12)
plt.ylabel('Jumlah', fontsize=12)
plt.xticks(rotation=45)
plt.show()
# Out:
# C:\Users\asus_utomo\AppData\Local\Temp\ipykernel_18124\1348059385.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=hari_counts.index, y=hari_counts.values, palette='viridis')

# %% [markdown]
# Menormalisasikan kolom Keperluan menjadi lowercase agar value tidak terlalu beragam

# %%
df_cleaned['Keperluan'] = df_cleaned['Keperluan'].str.lower()
df_cleaned.tail()
# Out:
#                Timestamp        Jurusan / Prodi  \
# 3317 2025-04-24 09:27:12        Sistem Komputer
# 3318 2025-04-24 10:40:30        Sistem Komputer
# 3319 2025-04-24 10:49:27        Teknik Komputer
# 3320 2025-04-24 11:39:51  Manajemen Informatika
# 3321 2025-04-24 11:56:27        Teknik Komputer
#
#                                       Nama Laboratorium  \
# 3317  Lab. Perangkat keras & Teknologi Komponen (Com...
# 3318    Lab. Elektronika & Sistem Digital (Comlab Lt.2)
# 3319      Lab. Jaringan Komputer & Komdat (Comlab Lt.2)
# 3320           Lab. Basis Data & Big Data (Comlab Lt.4)
# 3321                         RUANG Studio (Comlab Lt.4)
#
#                           Keperluan   Hari
# 3317                             ta  Kamis
# 3318                    tugas akhir  Kamis
# 3319                    tugas akhir  Kamis
# 3320  praktikum pemrograman visual   Kamis
# 3321    interaksi manusia komputer   Kamis

# %% [markdown]
# Memperbaiki typo pada data

# %%
df_cleaned['Keperluan'] = df_cleaned['Keperluan'].replace({'ta': 'tugas akhir', 'aslab': 'asisten lab', 'asleb': 'asisten lab'})
df_cleaned.tail()
# Out:
#                Timestamp        Jurusan / Prodi  \
# 3317 2025-04-24 09:27:12        Sistem Komputer
# 3318 2025-04-24 10:40:30        Sistem Komputer
# 3319 2025-04-24 10:49:27        Teknik Komputer
# 3320 2025-04-24 11:39:51  Manajemen Informatika
# 3321 2025-04-24 11:56:27        Teknik Komputer
#
#                                       Nama Laboratorium  \
# 3317  Lab. Perangkat keras & Teknologi Komponen (Com...
# 3318    Lab. Elektronika & Sistem Digital (Comlab Lt.2)
# 3319      Lab. Jaringan Komputer & Komdat (Comlab Lt.2)
# 3320           Lab. Basis Data & Big Data (Comlab Lt.4)
# 3321                         RUANG Studio (Comlab Lt.4)
#
#                           Keperluan   Hari
# 3317                    tugas akhir  Kamis
# 3318                    tugas akhir  Kamis
# 3319                    tugas akhir  Kamis
# 3320  praktikum pemrograman visual   Kamis
# 3321    interaksi manusia komputer   Kamis

# %%
plt.figure(figsize=(10, 10))
keperluan_counts = df_cleaned['Keperluan'].value_counts().head(10)  # Mengambil 10 keperluan teratas
keperluan_counts.plot(kind='pie', autopct='%1.1f%%', startangle=140, colormap='viridis')
plt.title('Distribusi data Keperluan 10 Teratas', fontsize=16)
plt.ylabel('')
plt.show()

# %% [markdown]
# Membuat kolom baru gabungan Jurusan / Prodi dan Hari

# %%
# df_cleaned['Jurusan_Hari'] = df_cleaned['Jurusan / Prodi'] + ' - ' + df_cleaned['Hari']
df_cleaned['Jurusan_Hari_Keperluan'] = df_cleaned['Jurusan / Prodi'] + ' - ' + df_cleaned['Hari'] + ' - ' + df_cleaned['Keperluan']

# %%
df_cleaned.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3322 entries, 0 to 3321
# Data columns (total 6 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Timestamp               3322 non-null   datetime64[ns]
#  1   Jurusan / Prodi         3322 non-null   object
#  2   Nama Laboratorium       3322 non-null   object
#  3   Keperluan               3322 non-null   object
#  4   Hari                    3322 non-null   object
#  5   Jurusan_Hari_Keperluan  3322 non-null   object
# dtypes: datetime64[ns](1), object(5)
# memory usage: 181.7+ KB

# %% [markdown]
# Mengubah format data menjadi daftar transaksi

# %%
transactions = df_cleaned[['Jurusan_Hari_Keperluan', 'Nama Laboratorium']].values.tolist()
print(transactions)
# Out:
# [['Manajemen Informatika - Kamis - kuliah', 'RUANG COMLAB 1.1'], ['Teknik Informatika Bilingual - Kamis - asisten lab', 'Lab. RPL & Sistem Informasi (Comlab Lt.3)'], ['Teknik Informatika Bilingual - Kamis - projek', 'Lab. Kecerdasan Buatan & Grafika Komp (Comlab Lt.2)'], ['Teknik Komputer - Kamis - peminjam kunci', 'Lab. Jaringan Komputer & Komdat (Comlab Lt.2)'], ['Komputerisasi Akuntansi - Kamis - praktikum zahir ', 'Lab. Struktur Data & SI Akuntansi (Comlab Lt.3)'], ['Sistem Komputer - Kamis - mengerjakan ta', 'Lab. Perangkat keras & Teknologi Komponen (Comlab Lt.3)'], ['Manajemen Informatika - Kamis - praktikum web programing 2', 'Lab. Pemograman Internet (Diklat Lt.5)'], ['Teknik Informatika Bilingual - Kamis - asisten lab', 'Lab. RPL & Sistem Informasi (Comlab Lt.3)'], ['Sistem Informasi Bilingual - Jumat - mata kuliah sistem operasi', 'Lab. Pemrograman Lanjut (Diklat Lt.4)'], ['Manajemen Informatika - Jumat - kuliah', 'Lab. Multimedia & Pemrograman Game (Comlab Lt.4)'], ['Komputerisasi Akuntansi - Jumat - praktikum akuntansi keuangan lanjut ', 'Lab. Struktur Data & SI Akuntansi (Comlab Lt.3)'], ['Komputerisasi Akuntansi - Jumat - praktikum basis data ', 'Lab. Struktur Data & SI Akuntansi (Comlab Lt.3)'], ['Manajemen Informatika - Jumat - pinjam kunci', 'RUANG COMLAB 1.1'], ['Komputerisasi Akuntansi - Jumat - praktikum basis data ', 'Lab. Struktur Data & SI Akuntansi (Comlab Lt.3)'], ['Manajemen Informatika - Jumat - basis data i', 'RUANG 3 A'], ['Manajemen Informatika - Jumat - praktikum paket program apk2', 'Lab. Pemrograman Dasar (Diklat Lt.3)'], ['Teknik Informatika Bilingual - Jumat - project ex-aslab', 'Lab. Pengolahan Citra & Pengenalan Pola (Comlab Lt.3)'], ['Manajemen Informatika - Jumat - kuliah', 'RUANG COMLAB 1.1'], ['Sistem Informasi Bilingual - Jumat - kelas', 'Lab. Pemrograman Internet (Diklat Lt.5)'], ['Manajemen Informatika - Senin - praktikum web programming ii', 'Lab. Pemrograman Internet (Diklat Lt.5)'], ['Sistem Informasi Bilingual - Senin - mata kuliah statistika', 'RUANG 3 A'], ['Manajemen Informatika - Senin - kuliah', 'RUANG COMLAB 1.1'], ['Sistem Komputer - Senin - tugas akhir', 'Lab. Robotika, Sistem Kendali & Sistem Tertanam (Comlab Lt.2)'], ['Teknik Komputer - Senin - kelas mk praktikum sistem operasi', 'Lab. Jaringan Komputer & Komdat (Comlab Lt.2)'], ['Manajemen Informatika - Senin - meminjam kunci ', 'Lab. Pemrograman Internet (Diklat Lt.5)'], ['Teknik Komputer - Senin - pembelajaran pemograman web ', 'Lab. Basis Data & Big Data (Comlab Lt.4)'], ['Teknik Informatika Bilingual - Senin - kuliah mk algoritma dan struktur data lanjut', 'Lab. Pemrograman Dasar (Diklat Lt.3)'], ['Teknik Informatika Bilingual - Senin - projek', 'Lab. Pengolahan Citra & Pengenalan Pola (Comlab Lt.3)'], ['Teknik Komputer - Senin - belajar mata kuliah pemrograman web', 'RUANG 3 A'], ['Komputerisasi Akuntansi - Senin - disain web', 'Lab. Struktur Data & SI Akuntansi (Comlab Lt.3)'], ['Manajemen Informatika - Senin - untuk mata kuliah sistem operasi', 'Lab. Pemrograman Dasar (Diklat Lt.3)'], ['Manajemen Informatika - Senin - kuliah', 'Lab. Multimedia & Pemrograman Game (Comlab Lt.4)'], ['Manajemen Informatika - Senin - kuliah prak multimedia i', 'Lab. Multimedia & Pemrograman Game (Comlab Lt.4)'], ['Sistem Informasi Bilingual - Senin - praktikum pemrograman web 1', 'Lab. Pemrograman Internet (Diklat Lt.5)'], ['Manajemen Informatika - Selasa - belajar ', 'RUANG 3 A'], ['Manajemen Informatika - Selasa - kuliah analisis dan perancangan sistem informasi i', 'RUANG COMLAB 1.1'], ['Komputerisasi Akuntansi - Selasa - praktikum struktur data dan basis data ', 'Lab. Struktur Data & SI Akuntansi (Comlab Lt.3)'], ['Teknik Komputer - Selasa - belajar', 'Lab. Elektronika & Sistem Digital (Comlab Lt.2)'], ['Teknik Komputer - Selasa - bimbingan ta dari pak zarkasi', 'Lab. Robotika, Sistem Kendali & Sistem Tertanam (Comlab Lt.2)'], ['Sistem Informasi Bilingual - Selasa - prak. analisis perancangan dan sistem informasi', 'Lab. RPL & S ...

# %% [markdown]
# Mengubah daftar transaksi menjadi format one-hot encoding

# %%
from mlxtend.preprocessing import TransactionEncoder

te = TransactionEncoder()
te_ary = te.fit(transactions).transform(transactions)
df_encoded = pd.DataFrame(te_ary, columns=te.columns_)

# %%
df_encoded
# Out:
#              Komputerisasi Akuntansi - Jumat - aslab mencari dokumen   \
# 0     False                                              False
# 1     False                                              False
# 2     False                                              False
# 3     False                                              False
# 4     False                                              False
# ...     ...                                                ...
# 3317  False                                              False
# 3318  False                                              False
# 3319  False                                              False
# 3320  False                                              False
# 3321  False                                              False
#
#       Komputerisasi Akuntansi - Jumat - desain web  \
# 0                                            False
# 1                                            False
# 2                                            False
# 3                                            False
# 4                                            False
# ...                                            ...
# 3317                                         False
# 3318                                         False
# 3319                                         False
# 3320                                         False
# 3321                                         False
#
#       Komputerisasi Akuntansi - Jumat - ka4  \
# 0                                     False
# 1                                     False
# 2                                     False
# 3                                     False
# 4                                     False
# ...                                     ...
# 3317                                  False
# 3318                                  False
# 3319                                  False
# 3320                                  False
# 3321                                  False
#
#       Komputerisasi Akuntansi - Jumat - kelas   \
# 0                                        False
# 1                                        False
# 2                                        False
# 3                                        False
# 4                                        False
# ...                                        ...
# 3317                                     False
# 3318                                     False
# 3319                                     False
# 3320                                     False
# 3321                                     False
#
#       Komputerisasi Akuntansi - Jumat - kelas praktikum desain web   \
# 0                                                 False
# 1                                                 False
# 2                                                 False
# 3                                                 False
# 4                                                 False
# ...                                                 ...
# 3317                                              False
# 3318                                              False
# 3319                                              False
# 3320                                              False
# 3321                                              False
#
#       Komputerisasi Akuntansi - Jumat - meminjam kelas  \
# 0                                                False
# 1                                                False
# 2                                                False
# 3                                                False
# 4                                                False
# ...                                                ...
# 3317                                             False
# 3318                                             False
# 3319                                             False
# 3320                                             False
# 3321                                             False
#
#       Komputerisasi Akuntansi - Jumat - meminjam kelas   \
# 0                                                 False
# 1                                                 False
# 2                                                 False
# 3                                                 False
# 4                                                 False
# ...                                                 ...
# 3317                                              False
# 3318                                              False
# 3319                                              False
# 3320                                              False
# 3321                                              False
#
#       Komputerisasi Akuntansi - Jumat - mengambil barang  \
# 0                                                 False
# 1                                                 False
# 2                                                 False
# 3                                                 False
# 4                                                 False
# ...                                                 ...
# 3317                                              False
# 3318                                              False
# 3319                                              False
# 3320                                              False
# 3321                                              False
#
#       Komputerisasi Akuntansi - Jumat - mk praktikum keuangan lanjut  ...  \
# 0                                                 False               ...
# 1                                                 False               ...
# 2                                                 False               ...
# 3                                                 False               ...
# 4                                                 False               ...
# ...                                                 ...               ...
# 3317                                              False               ...
# 3318                                              False               ...
# 3319                                              False               ...
# 3320                                              False               ...
# 3321                                              False               ...
#
#       Teknik Komputer - Senin - pratikum sistem kendali   \
# 0                                                 False
# 1                                                 False
# 2                                                 False
# 3                                                 False
# 4                                                 False
# ...                                                 ...
# 3317                                              False
# 3318                                              False
# 3319                                              False
# 3320                                              False
# 3321                                              False
#
#       Teknik Komputer - Senin - rekayasa perangkat lunak   \
# 0                                                 False
# 1                                                 False
# 2                                                 False
# 3                                                 False
# 4                                                 False
# ...                                                 ...
# 3317                                              False
# 3318                                              False
# 3319                                              False
# 3320                                              False
# 3321                                              False
#
#       Teknik Komputer - Senin - ruang belajar  \
# 0                                       False
# 1                                       False
# 2                                       False
# 3                                       False
# 4                                       False
# ...                                       ...
# 3317                                    False
# 3318                                    False
# 3319                                    False
# 3320                                    False
# 3321                                    False
#
#       Teknik Komputer - Senin - sistem kendali  \
# 0                                        False
# 1                                        False
# 2                                        False
# 3                                        False
# 4                                        False
# ...                                        ...
# 3317                                     False
# 3318                                     False
# 3319                                     False
# 3320                                     False
# 3321                                     False
#
#       Teknik Komputer - Senin - teori keamanan komputer  \
# 0                                                 False
# 1                                                 False
# 2                                                 False
# 3                                                 False
# 4                                                 False
# ...                                                 ...
# 3317                                              False
# 3318                                              False
# 3319                                              False
# 3320                                              False
# 3321                                              False
#
#       Teknik Komputer - Senin - tugas akhir  \
# 0                                     False
# 1                                     False
# 2                                     False
# 3                                     False
# 4                                     False
# ...                                     ...
# 3317                                  False
# 3318                                  False
# 3319                                  False
# 3320                                  False
# 3321                                  False
#
#       Teknik Komputer - Senin - tugas akhir   \
# 0                                      False
# 1                                      False
# 2                                      False
# 3                                      False
# 4                                      False
# ...                                      ...
# 3317                                   False
# 3318                                   False
# 3319                                   False
# 3320                                   False
# 3321                                   False
#
#       Teknik Komputer - Senin - untuk kelas matkul fisika  \
# 0                                                 False
# 1                                                 False
# 2                                                 False
# 3                                                 False
# 4                                                 False
# ...                                                 ...
# 3317                                              False
# 3318                                              False
# 3319                                              False
# 3320                                              False
# 3321                                              False
#
#       Teknik Komputer - Senin - untuk memasuki kelas  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
# ...                                              ...
# 3317                                           False
# 3318                                           False
# 3319                                           False
# 3320                                           False
# 3321                                           False
#
#       Teknik Komputer - Senin - untuk mencoba alat tugas akhir
# 0                                                 False
# 1                                                 False
# 2                                                 False
# 3                                                 False
# 4                                                 False
# ...                                                 ...
# 3317                                              False
# 3318                                              False
# 3319                                              False
# 3320                                              False
# 3321                                              False
#
# [3322 rows x 1741 columns]

# %% [markdown]
# Menjalankan Algoritma apriori untuk mencari frekuensi data

# %%
from mlxtend.frequent_patterns import apriori

frequent_itemsets = apriori(df_encoded, min_support=0.001, use_colnames=True)

# %% [markdown]
# Membuat aturan asosiasi berdasarkan itemset yang sering muncul

# %%
from mlxtend.frequent_patterns import association_rules

rules = association_rules(frequent_itemsets, metric="confidence", min_threshold=0.4)
rules = rules.sort_values(by='confidence', ascending=False)

# %% [markdown]
# Mengecek apakah rules kosong

# %%
print(rules.empty)
# Out:
# False

# %% [markdown]
# Menampilkan bebrapa fitur pada rules

# %%
rules[['antecedents', 'consequents', 'support', 'confidence', 'lift']]
# Out:
#                                            antecedents  \
# 0       (Komputerisasi Akuntansi - Jumat - desain web)
# 1    (Komputerisasi Akuntansi - Jumat - praktikum b...
# 2    (Komputerisasi Akuntansi - Jumat - praktikum b...
# 3    (Komputerisasi Akuntansi - Jumat - praktikum p...
# 4    (Komputerisasi Akuntansi - Jumat - praktikum s...
# ..                                                 ...
# 110             (Sistem Komputer - Rabu - tugas akhir)
# 111            (Sistem Komputer - Senin - tugas akhir)
# 27             (Sistem Komputer - Kamis - asisten lab)
# 126  (Sistem Informasi Bilingual - Senin - asisten ...
# 97              (Sistem Komputer - Rabu - tugas akhir)
#
#                                            consequents   support  confidence  \
# 0    (Lab. Struktur Data & SI Akuntansi (Comlab Lt.3))  0.001505    1.000000
# 1           (Lab. Basis Data & Big Data (Comlab Lt.4))  0.002408    1.000000
# 2    (Lab. Struktur Data & SI Akuntansi (Comlab Lt.3))  0.001204    1.000000
# 3          (Lab. RPL & Sistem Informasi (Comlab Lt.3))  0.002408    1.000000
# 4    (Lab. Perangkat keras & Teknologi Komponen (Co...  0.001204    1.000000
# ..                                                 ...       ...         ...
# 110  (Lab. Robotika, Sistem Kendali & Sistem Tertan...  0.004816    0.457143
# 111  (Lab. Robotika, Sistem Kendali & Sistem Tertan...  0.006321    0.437500
# 27   (Lab. Elektronika & Sistem Digital (Comlab Lt.2))  0.002709    0.428571
# 126  (Lab. Struktur Data & SI Akuntansi (Comlab Lt.3))  0.001806    0.428571
# 97   (Lab. Perangkat keras & Teknologi Komponen (Co...  0.004214    0.400000
#
#           lift
# 0    12.036232
# 1    18.875000
# 2    12.036232
# 3    13.341365
# 4    16.527363
# ..         ...
# 110   9.093584
# 111   8.702844
# 27    4.995489
# 126   5.158385
# 97    6.610945
#
# [141 rows x 5 columns]

# %% [markdown]
# Menampilkan hasil dalam bentuk kalimat

# %%
for index, row in rules.iterrows():
    print(f"Jika {set(row['antecedents'])} maka {set(row['consequents'])} dengan confidence {row['confidence']:.2f} dan lift {row['lift']:.2f}")
# Out:
# Jika {'Komputerisasi Akuntansi - Jumat - desain web'} maka {'Lab. Struktur Data & SI Akuntansi (Comlab Lt.3)'} dengan confidence 1.00 dan lift 12.04
# Jika {'Komputerisasi Akuntansi - Jumat - praktikum basis data'} maka {'Lab. Basis Data & Big Data (Comlab Lt.4)'} dengan confidence 1.00 dan lift 18.88
# Jika {'Komputerisasi Akuntansi - Jumat - praktikum basis data '} maka {'Lab. Struktur Data & SI Akuntansi (Comlab Lt.3)'} dengan confidence 1.00 dan lift 12.04
# Jika {'Komputerisasi Akuntansi - Jumat - praktikum pemrograman bergerak '} maka {'Lab. RPL & Sistem Informasi (Comlab Lt.3)'} dengan confidence 1.00 dan lift 13.34
# Jika {'Komputerisasi Akuntansi - Jumat - praktikum sistem informasi akutansi '} maka {'Lab. Perangkat keras & Teknologi Komponen (Comlab Lt.3)'} dengan confidence 1.00 dan lift 16.53
# Jika {'Komputerisasi Akuntansi - Jumat - pratikum disen web '} maka {'Lab. Struktur Data & SI Akuntansi (Comlab Lt.3)'} dengan confidence 1.00 dan lift 12.04
# Jika {'Komputerisasi Akuntansi - Rabu - praktikum desain web '} maka {'Lab. Pemrograman Lanjut (Diklat Lt.4)'} dengan confidence 1.00 dan lift 11.91
# Jika {'Komputerisasi Akuntansi - Selasa - praktikum akuntansi dasar '} maka {'Lab. Struktur Data & SI Akuntansi (Comlab Lt.3)'} dengan confidence 1.00 dan lift 12.04
# Jika {'Manajemen Informatika - Jumat - kuliah praktikum basis data ii'} maka {'Lab. Basis Data & Big Data (Comlab Lt.4)'} dengan confidence 1.00 dan lift 18.88
# Jika {'Komputerisasi Akuntansi - Senin - zahir accounting '} maka {'Lab. Struktur Data & SI Akuntansi (Comlab Lt.3)'} dengan confidence 1.00 dan lift 12.04
# Jika {'Komputerisasi Akuntansi - Senin - pratikum struktur data '} maka {'Lab. Struktur Data & SI Akuntansi (Comlab Lt.3)'} dengan confidence 1.00 dan lift 12.04
# Jika {'Komputerisasi Akuntansi - Senin - praktikum akuntansi keuangan menengah '} maka {'Lab. RPL & Sistem Informasi (Comlab Lt.3)'} dengan confidence 1.00 dan lift 13.34
# Jika {'Komputerisasi Akuntansi - Selasa - praktikum struktur data'} maka {'Lab. Pemrograman Lanjut (Diklat Lt.4)'} dengan confidence 1.00 dan lift 11.91
# Jika {'Sistem Informasi Bilingual - Senin - jaga lab - aslab'} maka {'Lab. Struktur Data & SI Akuntansi (Comlab Lt.3)'} dengan confidence 1.00 dan lift 12.04
# Jika {'Sistem Informasi Bilingual - Selasa - jaga lab - aslab'} maka {'Lab. Struktur Data & SI Akuntansi (Comlab Lt.3)'} dengan confidence 1.00 dan lift 12.04
# Jika {'Manajemen Informatika - Rabu - mata kuliah praktikum basis data 1 '} maka {'Lab. Struktur Data & SI Akuntansi (Comlab Lt.3)'} dengan confidence 1.00 dan lift 12.04
# Jika {'Sistem Informasi Bilingual - Kamis - jaga lab - aslab'} maka {'Lab. Struktur Data & SI Akuntansi (Comlab Lt.3)'} dengan confidence 1.00 dan lift 12.04
# Jika {'Sistem Informasi Bilingual - Rabu - tugas jaga lab'} maka {'Lab. Struktur Data & SI Akuntansi (Comlab Lt.3)'} dengan confidence 1.00 dan lift 12.04
# Jika {'Manajemen Informatika - Kamis - kuliah praktikum pemrograman visual'} maka {'Lab. Basis Data & Big Data (Comlab Lt.4)'} dengan confidence 1.00 dan lift 18.88
# Jika {'Manajemen Informatika - Senin - praktikum desain grafis '} maka {'Lab. Basis Data & Big Data (Comlab Lt.4)'} dengan confidence 1.00 dan lift 18.88
# Jika {'Manajemen Informatika - Kamis - ruang kelas '} maka {'Lab. Basis Data & Big Data (Comlab Lt.4)'} dengan confidence 1.00 dan lift 18.88
# Jika {'Sistem Komputer - Kamis - skripsi'} maka {'Lab. Elektronika & Sistem Digital (Comlab Lt.2)'} dengan confidence 1.00 dan lift 11.66
# Jika {'Sistem Komputer - Jumat - skripsi'} maka {'Lab. Elektronika & Sistem Digital (Comlab Lt.2)'} dengan confidence 1.00 dan lift 11.66
# Jika {'Sistem Komputer - Senin - mengerjakan skripsi'} maka {'Lab. Jaringan Komputer & Komdat (Comlab Lt.2)'} dengan confidence 1.00 dan lift 10.86
# Jika {'Sistem Komputer - Jumat - mengerjakan skripsi'} maka {'Lab. Jaringan Komputer & Komdat (Comlab Lt.2)'} dengan confidence 1.00 dan lift 10.86
# Jika {'Sistem Komputer - Selasa - skripsi'} maka {'Lab. Elektronika & Sistem Digital (Comlab Lt.2)'} dengan confidence 1.00 dan lift 11.66
# Jika {'Sistem Komputer - Senin - skripsi'} maka {'Lab. Elektronika & Sistem Digital (Comlab Lt.2)'} dengan confidence 1.00 dan lift 11.66
# Jika {'Sistem Komputer - Rabu - skripsi'} maka {'Lab. Elektronika & Sistem Digital (Comlab Lt.2)'} dengan confidence 1.00 dan lift 11.66
# Jika {'Sistem Komputer - Selasa - praktikum rangkaian listrik '} maka {'Lab. Elektronika & Sistem Digital (Comlab Lt.2)'} dengan confidence 1.00 dan lift 11.66
# Jika {'Manajemen Informatika - Rabu - kuliah praktikum jaringan komputer'} maka {'Lab. Jaringan Komputer & Komdat (Comlab Lt.2)'} dengan confidence 1.00 dan lift 10.86
# Jika {'Teknik Informatika Bilingual - Kamis - pemrograman komputer lanjut'} maka {'Lab. Pemrograman Dasar (Diklat Lt.3)'} dengan confidence 1.00 dan lift 14.44
# Jika {'Teknik Informatika Bilingual - Kamis - pratikum basis data'} maka {'Lab. Pemrograman Dasar (Diklat Lt.3)'} dengan confidence 1.00 dan lift 14.44
# Jika {'Teknik Informatika Bilingual - Selasa - algoritma dan struktur data lanjut'} maka {'Lab. Pemrograman Dasar (Diklat Lt.3)'} dengan confidence 1.00 dan lift 14.44
# Jika {'Teknik Informatika Bilingual - Selasa - praktikum pemrograman komputer lanjut'} maka {'Lab. Pemrograman Dasar (Diklat Lt.3)'} dengan confidence 1.00 dan lift 14.44
# Jika {'Teknik Informatika Bilingual - Selasa - meminjam kunci untuk belajar'} maka {'Lab. Pemrograman Dasar (Diklat Lt.3)'} dengan confidence 1.00 dan lift 14.44
# Jika {'Manajemen Informatika - Rabu - matakuliah praktikum web programming ii'} maka {'Lab. Pemrograman Internet (Diklat Lt.5)'} dengan confidence 1.00 dan lift 14.44
# Jika {'Manajemen Informatika - Kamis - mata kuliah '} maka {'Lab. Pemrograman Internet (Diklat Lt.5)'} dengan confidence 1.00 dan lift 14.44
# Jika {'Manajemen Informatika - Rabu - kegiatan belajar kuliah'} maka {'Lab. Multimedia & Pemrograman Game (Comlab Lt.4)'} dengan confidence 1.00 dan lift 18.98
# Jika {'Manajemen Informatika - Senin - kegiatan belajar kuliah'} maka {'Lab. Multimedia & Pemrograman Game (Comlab Lt.4)'} dengan confidence 1.00 dan lift 18.98
# Jika {'Teknik Informatika Bilingual - Selasa - asisten lab '} maka {'Lab. Multimedia & Pemrograman Game (Comlab Lt.4)'} dengan confidence 1.00 dan lift 18.98
# Jika {'Teknik Informatika Bilingual - Rabu - asisten lab '} maka {'Lab. Multimedia & Pemrograman Game (Comlab Lt.4)'} dengan confidence 1.00 dan lift 18.98
# Jika {'Manajemen Informatika - Senin - matakuliah praktikum sistem operasi'} maka {'Lab. Pemrograman Dasar (Diklat Lt.3)'} dengan confidence 1.00 dan lift 14.44
# Jika {'Teknik Komputer - Rabu - praktikum jaringan komputer '} maka {'Lab. Jaringan Komputer & Komdat (Comlab Lt.2)'} dengan confidence 1.00 dan lift 10.86
# Jika {'Teknik Komputer - Kamis - ada mata kuliah praktikum'} maka {'Lab. Jaringan Komputer & Komdat (Comlab Lt.2)'} dengan confidence 1.00 dan lift 10.86
# Jika {'Sistem Komputer - Senin - tugas akhir dengan pak ahmad heryanto '} maka {'Lab. Jaringan Komputer & Komdat (Comlab Lt.2)'} dengan confidence 1.00 dan lift 10.86
# Jika {'Sistem Komputer - Senin - organisasi dan arsitektur komputer'} maka {'Lab. Pemrograman Internet (Diklat Lt.5)'} dengan confidence 1.00 dan lift 14.44
# Jika {'Sistem Komputer - Senin - mata kuliah data mining'} maka {'Lab. Pemrograman Internet (Diklat Lt.5)'} dengan confidence 1.00 dan lift 14.44
# Jika {'Manajemen Informatika - Senin - praktikum web programming ii'} maka {'Lab. Pemrograman Internet (Diklat Lt.5)'} dengan confidence 1.00 dan lift 14.44
# Jika {'Sistem Informasi Bilingual - Senin - praktikum pemrograman web 1'} maka {'Lab. Pemrograman Internet (Diklat Lt.5)'} dengan confidence 1.00 dan lift 14.44
# Jika {'Teknik Informatika Bilingual - Kamis - pratikum pemrograman komputer lanjut'} maka {'Lab. Pemrograman Internet (Diklat Lt.5)'} dengan confidence 1.00 dan lift 14.44
# Jika {'Teknik Informatika Bilingual - Kamis - meminjam kunci untuk belajar'} maka {'Lab. Pemrograman Dasar (Diklat Lt.3)'} dengan confidence 1.00 dan lift 14.44
# Jika {'Manajemen Informatika - Rabu - mk praktikum basis data '} maka {'Lab. Struktur Data & SI Akuntansi (Comlab Lt.3)'} dengan confidence 1.00 dan lift 12.04
# Jika {'Teknik Komputer - Kamis - mk interaksi manusia komputer '} maka {'RUANG Studio (Comlab Lt.4)'} dengan confidence 1.00 dan lift 32.89
# Jika {'Manajemen Informatika - Senin - kuliah praktikum pemrograman berorientasi objek'} maka {'RUANG 3 A'} dengan confidence 1.00 dan lift 22.30
# Jika {'Teknik Komputer - Senin - jaringan komputer '} maka {'RUANG Studio (Comlab Lt.4)'} dengan confidence 1.00 dan lift 32.89
# Jika {'Teknik Komputer - Rabu - komputasi bergerak '} maka {'RUANG Studio (Comlab Lt.4)'} dengan confidence 1.00 dan lift 32.89
# Jika {'Teknik Komputer - Senin - rekayasa perangkat lunak '} maka {'Lab. Studio (Comlab Lt.4)'} dengan confidence 1.00 dan lift 30.48
# Jika {'Manajemen Informatika - Kamis - matakuliah'} maka {'Lab. Studio (Comlab Lt.4)'} dengan confidence 1.00 dan lift 30.48
# Jika {'Teknik Informatika Bilingual - Selasa - praktikum'} maka {'Lab. Struktur Data & SI Akuntansi (Comlab Lt.3)'} dengan confidence 1.00 dan lift 12.04
# Jika {'Sistem Informasi Bilingual - Jumat - asisten lab '} maka {'Lab. RPL & Sistem Informasi (Comlab Lt.3)'} dengan confidence 1.00 dan lift 13.34
# Jika {'Teknik Informatika Bilingual - Senin - tugas akhir '} maka {'Lab. Pengolahan Citra & Pengenalan Pola (Comlab Lt.3)'} dengan confidence 1.00 dan lift 17.67
# Jika {'Teknik Informatika Bilingual - Selasa - tugas akhir '} maka {'Lab. Pengolahan Citra & Pengenalan Pola (Comlab Lt.3)'} dengan confidence 1.00 dan lift 17.67
# Jika {'Teknik Informatika Bilingual - Senin - aslab/tugas akhir '} maka {'Lab. Pengolahan Citra & Pengenalan Pola (Comlab Lt.3)'} dengan confidence 1.00 dan lift 17.67
# Jika {'Teknik Informatika Bilingual - Selasa - aslab/tugas akhir '} maka {'Lab. Pengolahan Citra & Pengenalan Pola (Comlab Lt.3)'} dengan confidence 1.00 dan lift 17.67
# Jika {'Teknik Informatika Bilingual - Rabu - tugas akhir '} maka {'Lab. Pengolahan Citra & Pengenalan Pola (Comlab Lt.3)'} dengan confidence 1.00 dan lift 17.67
# Jika {'Teknik Informatika Bilingual - Kamis - aslab/tugas akhir '} maka {'Lab. Pengolahan Citra & Pengenalan Pola (Comlab Lt.3)'} dengan confidence 1.00 dan lift 17.67
# Jika {'Teknik Informatika Bilingual - Jumat - tugas akhir '} maka {'Lab. Pengolahan Citra & Pengenalan Pola (Comlab Lt.3)'} dengan confidence 1.00 dan lift 17.67
# Jika {'Teknik Informatika Bilingual - Rabu - aslab/tugas akhir '} maka {'Lab. Pengolahan Citra & Pengenalan Pola (Comlab Lt.3)'} dengan confidence 1.00 dan lift 17.67
# Jika {'Teknik Informatika Bilingual - Kamis - tugas akhir '} maka {'Lab. Pengolahan Citra & Pengenalan Pola (Comlab Lt.3)'} dengan confidence 1.00 dan lift 17.67
# Jika {'Sistem Komputer - Kamis - praktikum pemrograman komputer'} maka {'Lab. Pemrograman Lanjut (Diklat Lt.4)'} dengan confidence 1.00 dan lift 11.91
# Jika {'Teknik Informatika Bilingual - Jumat - aslab/tugas akhir '} maka {'Lab. Pengolahan Citra & Pengenalan Pola (Comlab Lt.3)'} dengan confidence 1.00 dan lift 17.67
# Jika {'Sistem Informasi Bilingual - Rabu - praktikum pemrograman web 1 '} maka {'Lab. Pemrograman Lanjut (Diklat Lt.4)'} dengan confidence 1.00 dan lift 11.91
# Jika {'Sistem Komputer - Kamis - mk praktikum pemrograman komputer '} maka {'Lab. Pemrograman Lanjut (Diklat Lt.4)'} dengan confidence 1.00 dan lift 11.91
# Jika {'Sistem Informasi Bilingual - Rabu - mata kuliah praktikum pemrograman bergerak'} maka {'Lab. Pemrograman Lanjut (Diklat Lt.4)'} dengan confidence 1.00 dan lift 11.91
# Jika {'Sistem Informasi Bilingual - Kamis - meminjam kunci lab'} maka {'Lab. Pemrograman Lanjut (Diklat Lt.4)'} dengan confidence 1.00 dan lift 11.91
# Jika {'Sistem Informasi Bilingual - Kamis - kelas etika profesi '} maka {'Lab. Pemrograman Lanjut (Diklat Lt.4)'} dengan confidence 1.00 dan lift 11.91
# Jika {'Sistem Informasi Bilingual - Jumat - praktikum pem web 1'} maka {'Lab. Pemrograman Lanjut (Diklat Lt.4)'} dengan confidence 1.00 dan lift 11.91
# Jika {'Sistem Informasi Bilingual - Jumat - tugas jaga lab'} maka {'Lab. Struktur Data & SI Akuntansi (Comlab Lt.3)'} dengan confidence 1.00 dan lift 12.04
# Jika {'Sistem Informasi Bilingual - Kamis - tugas jaga lab'} maka {'Lab. Struktur Data & SI Akuntansi (Comlab Lt.3)'} dengan confidence 1.00 dan lift 12.04
# Jika {'Teknik Komputer - Selasa - jadwal kelas'} maka {'Lab. RPL & Sistem Informasi (Comlab Lt.3)'} dengan confidence 1.00 dan lift 13.34
# Jika {'Sistem Informasi Bilingual - Kamis - asisten lab '} maka {'Lab. RPL & Sistem Informasi (Comlab Lt.3)'} dengan confidence 0.93 dan lift 12.45
# Jika {'Komputerisasi Akuntansi - Rabu - praktikum desain web'} maka {'Lab. Pemrograman Lanjut (Diklat Lt.4)'} dengan confidence 0.91 dan lift 10.82
# Jika {'Manajemen Informatika - Selasa - kuliah praktikum animasi komputer'} maka {'Lab. Basis Data & Big Data (Comlab Lt.4)'} dengan confidence 0.90 dan lift 16.99
# Jika {'Sistem Informasi Bilingual - Rabu - asisten lab '} maka {'Lab. RPL & Sistem Informasi (Comlab Lt.3)'} dengan confidence 0.90 dan lift 12.01
# Jika {'Manajemen Informatika - Rabu - praktikum basis data i'} maka {'Lab. Pemrograman Internet (Diklat Lt.5)'} dengan confidence 0.88 dan lift 12.64
# Jika {'Manajemen Informatika - Kamis - praktikum multimedia i '} maka {'Lab. Struktur Data & SI Akuntansi (Comlab Lt.3)'} dengan confidence 0.86 dan lift 10.32
# Jika {'Teknik Komputer - Kamis - belajar'} maka {'RUANG COMLAB 1.1'} dengan confidence 0.86 dan lift 17.69
# Jika {'Sistem Informasi Bilingual - Selasa - asisten lab'} maka {'Lab. RPL & Sistem Informasi (Comlab Lt.3)'} dengan confidence 0.86 dan lift 11.44
# Jika {'Komputerisasi Akuntansi - Kamis - pratikum zahir accounting '} maka {'Lab. Struktur Data & SI Akuntansi (Comlab Lt.3)'} dengan confidence 0.86 dan lift 10.32
# Jika {'Manajemen Informatika - Jumat - kuliah multimedia ii'} maka {'Lab. Pemrograman Dasar (Diklat Lt.3)'} dengan confidence 0.86 dan lift 12.38
# Jika {'Sistem Informasi Bilingual - Senin - asisten lab '} maka {'Lab. RPL & Sistem Informasi (Comlab Lt.3)'} dengan confidence 0.83 dan lift 11.12
# Jika {'Teknik Komputer - Kamis - praktikum sistem operasi'} maka {'Lab. Jaringan Komputer & Komdat (Comlab Lt.2)'} dengan confidence 0.83 dan lift 9.05
# Jika {'Sistem Komputer - Selasa - materi'} maka {'Lab. Pemrograman Dasar (Diklat Lt.3)'} dengan confidence 0.83 dan lift 12.04
# Jika {'Manajemen Informatika - Selasa - matakuliah'} maka {'Lab. Basis Data & Big Data (Comlab Lt.4)'} dengan confidence 0.83 dan lift 15.73
# Jika {'Sistem Informasi Bilingual - Selasa - asisten lab '} maka {'Lab. RPL & Sistem Informasi (Comlab Lt.3)'} dengan confidence 0.83 dan lift 11.12
# Jika {'Manajemen Informatika - Jumat - kuliah praktikum basis data'} maka {'Lab. Basis Data & Big Data (Comlab Lt.4)'} dengan confidence 0.83 dan lift 15.73
# Jika {'Sistem Komputer - Jumat - belajar'} maka {'Lab. Elektronika & Sistem Digital (Comlab Lt.2)'} dengan confidence 0.83 dan lift 9.71
# Jika {'Teknik Komputer - Jumat - kecerdasan buatan '} maka {'RUANG Studio (Comlab Lt.4)'} dengan confidence 0.82 dan lift 26.91
# Jika {'Komputerisasi Akuntansi - Selasa - praktikum anggaran '} maka {'Lab. Multimedia & Pemrograman Game (Comlab Lt.4)'} dengan confidence 0.80 dan lift 15.19
# Jika {'Komputerisasi Akuntansi - Kamis - praktikum algoritma dan pemrograman '} maka {'Lab. Pemrograman Lanjut (Diklat Lt.4)'} dengan confidence 0.80 dan lift 9.53
# Jika {'Komputerisasi Akuntansi - Rabu - pratikum basis data '} maka {'Lab. Basis Data & Big Data (Comlab Lt.4)'} dengan confidence 0.80 dan lift 15.10
# Jika {'Teknik Komputer - Rabu - belajar '} maka {'RUANG 3 A'} dengan confidence 0.80 dan lift 17.84
# Jika {'Sistem Komputer - Rabu - belajar'} maka {'Lab. Elektronika & Sistem Digital (Comlab Lt.2)'} dengan confidence 0.80 dan lift 9.32
# Jika {'Sistem Informasi Bilingual - Selasa - praktikum basis data ii'} maka {'Lab. Pemrograman Lanjut (Diklat Lt.4)'} dengan confidence 0.80 dan lift 9.53
# Jika {'Sistem Informasi Bilingual - Kamis - mata kuliah multimedia'} maka {'RUANG COMLAB 1.1'} dengan confidence 0.80 dan lift 16.51
# Jika {'Teknik Komputer - Kamis - tugas akhir '} maka {'Lab. Robotika, Sistem Kendali & Sistem Tertanam (Comlab Lt.2)'} dengan confidence 0.80 dan lift 15.91
# Jika {'Teknik Komputer - Jumat - tugas akhir '} maka {'Lab. Robotika, Sistem Kendali & Sistem Tertanam (Comlab Lt.2)'} dengan confidence 0.80 dan lift 15.91
# Jika {'Teknik Informatika Bilingual - Rabu - mata kuliah grafika komputer'} maka {'Lab. Pemrograman Dasar (Diklat Lt.3)'} dengan confidence 0.78 dan lift 11.23
# Jika {'Teknik Komputer - Senin - tugas akhir '} maka {'Lab. Robotika, Sistem Kendali & Sistem Tertanam (Comlab Lt.2)'} dengan confidence 0.75 dan lift 14.92
# Jika {'Manajemen Informatika - Selasa - praktikum animasi komputer '} maka {'Lab. Multimedia & Pemrograman Game (Comlab Lt.4)'} dengan confidence 0.73 dan lift 13.92
# Jika {'Sistem Komputer - Jumat - asisten lab'} maka {'Lab. Jaringan Komputer & Komdat (Comlab Lt.2)'} dengan confidence 0.72 dan lift 7.84
# Jika {'Teknik Komputer - Rabu - tugas akhir'} maka {'Lab. Robotika, Sistem Kendali & Sistem Tertanam (Comlab Lt.2)'} dengan confidence 0.71 dan lift 14.21
# Jika {'Sistem Informasi Bilingual - Jumat - jaga lab - aslab'} maka {'Lab. Struktur Data & SI Akuntansi (Comlab Lt.3)'} dengan confidence 0.71 dan lift 8.60
# Jika {'Manajemen Informatika - Kamis - praktikum pemrograman visual '} maka {'Lab. RPL & Sistem Informasi (Comlab Lt.3)'} dengan confidence 0.71 dan lift 9.53
# Jika {'Teknik Komputer - Selasa - tugas akhir'} maka {'Lab. Jaringan Komputer & Komdat (Comlab Lt.2)'} dengan confidence 0.71 dan lift 7.75
# Jika {'Manajemen Informatika - Selasa - praktikum paket program aplikasi ii'} maka {'RUANG COMLAB 1.1'} dengan confidence 0.67 dan lift 13.76
# Jika {'Sistem Informasi Bilingual - Rabu - jaga lab - aslab'} maka {'Lab. Struktur Data & SI Akuntansi (Comlab Lt.3)'} dengan confidence 0.67 dan lift 8.02
# Jika {'Sistem Komputer - Senin - belajar'} maka {'Lab. Elektronika & Sistem Digital (Comlab Lt.2)'} dengan confidence 0.67 dan lift 7.77
# Jika {'Teknik Komputer - Selasa - praktikum'} maka {'Lab. Elektronika & Sistem Digital (Comlab Lt.2)'} dengan confidence 0.67 dan lift 7.77
# Jika {'Teknik Komputer - Senin - tugas akhir'} maka {'Lab. Jaringan Komputer & Komdat (Comlab Lt.2)'} dengan confidence 0.67 dan lift 7.24
# Jika {'Manajemen Informatika - Senin - praktikum desain grafis'} maka {'Lab. Multimedia & Pemrograman Game (Comlab Lt.4)'} dengan confidence 0.67 dan lift 12.66
# Jika {'Sistem Informasi Bilingual - Kamis - kelas'} maka {'Lab. Pemrograman Lanjut (Diklat Lt.4)'} dengan confidence 0.67 dan lift 7.94
# Jika {'Teknik Komputer - Senin - praktikum sistem kendali '} maka {'Lab. Studio (Comlab Lt.4)'} dengan confidence 0.67 dan lift 20.32
# Jika {'Teknik Komputer - Kamis - tugas akhir'} maka {'Lab. Jaringan Komputer & Komdat (Comlab Lt.2)'} dengan confidence 0.62 dan lift 6.79
# Jika {'Manajemen Informatika - Kamis - praktikum multimedia '} maka {'Lab. Multimedia & Pemrograman Game (Comlab Lt.4)'} dengan confidence 0.62 dan lift 11.86
# Jika {'Sistem Informasi Bilingual - Rabu - asisten lab'} maka {'Lab. RPL & Sistem Informasi (Comlab Lt.3)'} dengan confidence 0.62 dan lift 8.34
# Jika {'Sistem Komputer - Selasa - asisten lab'} maka {'Lab. Jaringan Komputer & Komdat (Comlab Lt.2)'} dengan confidence 0.62 dan lift 6.74
# Jika {'Sistem Komputer - Senin - asisten lab'} maka {'Lab. Jaringan Komputer & Komdat (Comlab Lt.2)'} dengan confidence 0.58 dan lift 6.33
# Jika {'Manajemen Informatika - Kamis - kegiatan belajar kuliah'} maka {'Lab. Basis Data & Big Data (Comlab Lt.4)'} dengan confidence 0.58 dan lift 11.01
# Jika {'Sistem Informasi Bilingual - Kamis - asisten lab'} maka {'Lab. RPL & Sistem Informasi (Comlab Lt.3)'} dengan confidence 0.57 dan lift 7.62
# Jika {'Sistem Informasi Bilingual - Senin - asisten lab'} maka {'Lab. RPL & Sistem Informasi (Comlab Lt.3)'} dengan confidence 0.57 dan lift 7.62
# Jika {'Sistem Komputer - Kamis - asisten lab'} maka {'Lab. Jaringan Komputer & Komdat (Comlab Lt.2)'} dengan confidence 0.57 dan lift 6.20
# Jika {'Sistem Komputer - Selasa - tugas akhir'} maka {'Lab. Perangkat keras & Teknologi Komponen (Comlab Lt.3)'} dengan confidence 0.56 dan lift 9.27
# Jika {'Sistem Komputer - Rabu - asisten lab'} maka {'Lab. Elektronika & Sistem Digital (Comlab Lt.2)'} dengan confidence 0.53 dan lift 6.22
# Jika {'Sistem Komputer - Jumat - tugas akhir'} maka {'Lab. Perangkat keras & Teknologi Komponen (Comlab Lt.3)'} dengan confidence 0.49 dan lift 8.07
# Jika {'Sistem Komputer - Rabu - asisten lab'} maka {'Lab. Jaringan Komputer & Komdat (Comlab Lt.2)'} dengan confidence 0.47 dan lift 5.07
# Jika {'Sistem Komputer - Rabu - tugas akhir'} maka {'Lab. Robotika, Sistem Kendali & Sistem Tertanam (Comlab Lt.2)'} dengan confidence 0.46 dan lift 9.09
# Jika {'Sistem Komputer - Senin - tugas akhir'} maka {'Lab. Robotika, Sistem Kendali & Sistem Tertanam (Comlab Lt.2)'} dengan confidence 0.44 dan lift 8.70
# Jika {'Sistem Komputer - Kamis - asisten lab'} maka {'Lab. Elektronika & Sistem Digital (Comlab Lt.2)'} dengan confidence 0.43 dan lift 5.00
# Jika {'Sistem Informasi Bilingual - Senin - asisten lab'} maka {'Lab. Struktur Data & SI Akuntansi (Comlab Lt.3)'} dengan confidence 0.43 dan lift 5.16
# Jika {'Sistem Komputer - Rabu - tugas akhir'} maka {'Lab. Perangkat keras & Teknologi Komponen (Comlab Lt.3)'} dengan confidence 0.40 dan lift 6.61

# %% [markdown]
# Menyimpan rules untuk digunakan pada UI

# %%
# rules['antecedents'] = rules['antecedents'].apply(lambda x: str(set(x)))
# rules['consequents'] = rules['consequents'].apply(lambda x: str(set(x)))
# rules.to_csv('rules2.csv', index=False)
